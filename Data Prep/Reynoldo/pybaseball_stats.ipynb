# %%
# !pip install pybaseball

# %%
import pandas as pd
from pybaseball import pitching_stats
from pybaseball import batting_stats 

pd.options.display.max_columns = None

# %%
batting_stats_df = batting_stats(2019, 2020)
batting_stats_df.head()
# Out:
#      Season              Name       Team   Age      G     AB     PA      H  \
# 33   2019.0        Mike Trout     Angels  27.0  134.0  470.0  600.0  137.0
# 48   2019.0      Alex Bregman     Astros  25.0  156.0  554.0  690.0  164.0
# 28   2019.0  Christian Yelich    Brewers  27.0  130.0  489.0  580.0  161.0
# 55   2019.0    Cody Bellinger    Dodgers  23.0  156.0  558.0  660.0  170.0
# 177  2019.0     Marcus Semien  Athletics  28.0  162.0  657.0  747.0  187.0
#
#         1B    2B   3B    HR      R    RBI     BB   IBB     SO   HBP   SF   SH  \
# 33    63.0  27.0  2.0  45.0  110.0  104.0  110.0  14.0  120.0  16.0  4.0  0.0
# 48    84.0  37.0  2.0  41.0  122.0  112.0  119.0   2.0   83.0   9.0  8.0  0.0
# 28    85.0  29.0  3.0  44.0  100.0   97.0   80.0  16.0  118.0   8.0  3.0  0.0
# 55    86.0  34.0  3.0  47.0  121.0  115.0   95.0  21.0  108.0   3.0  4.0  0.0
# 177  104.0  43.0  7.0  33.0  123.0   92.0   87.0   2.0  102.0   2.0  1.0  0.0
#
# ...

# %%
angels_df = batting_stats_df[batting_stats_df['Team'] == 'Angels']
angels_df.head()
# Out:
#      Season            Name    Team   Age      G     AB     PA      H     1B  \
# 33   2019.0      Mike Trout  Angels  27.0  134.0  470.0  600.0  137.0   63.0
# 521  2019.0  David Fletcher  Angels  25.0  154.0  596.0  653.0  173.0  133.0
# 117  2020.0  Anthony Rendon  Angels  30.0   50.0  182.0  223.0   50.0   30.0
# 61   2020.0      Mike Trout  Angels  28.0   51.0  191.0  232.0   55.0   28.0
# 424  2019.0    Kole Calhoun  Angels  31.0  152.0  552.0  632.0  128.0   65.0
#
#        2B   3B    HR      R    RBI     BB   IBB     SO   HBP   SF   SH   GDP  \
# 33   27.0  2.0  45.0  110.0  104.0  110.0  14.0  120.0  16.0  4.0  0.0   5.0
# 521  30.0  4.0   6.0   83.0   49.0   55.0   2.0   64.0   0.0  1.0  1.0   8.0
# 117  10.0  1.0   9.0   28.0   31.0   36.0   2.0   31.0   5.0  0.0  0.0   8.0
# 61    9.0  2.0  16.0   40.0   43.0   34.0   4.0   53.0   3.0  4.0  0.0   1.0
# 424  29.0  1.0  33.0   92.0   74.0   70.0   7.0  162.0   7.0  2.0  0.0  14.0
#
# ...

# %%
# pitching_stats_df = pitching_stats(2019, 2020)
# pitching_stats_df.head()
